# %%
import pandas as pd

# %%
qb_1 = pd.read_csv('best_ball_qb.csv')
qb_2 = pd.read_csv('best_ball_qb2.csv')
qb_3 = pd.read_csv('best_ball_qb3.csv')
qb_4 = pd.read_csv('best_ball_qb4.csv')
qb_5 = pd.read_csv('best_ball_qb5.csv')
qb_6 = pd.read_csv('best_ball_qb6.csv')
qb_7 = pd.read_csv('best_ball_qb7.csv')
qb_8 = pd.read_csv('best_ball_qb8.csv')
qb_9 = pd.read_csv('best_ball_qb9.csv')
qb_10 = pd.read_csv('best_ball_qb10.csv')
qb_11 = pd.read_csv('best_ball_qb11.csv')
qb_12 = pd.read_csv('best_ball_qb12.csv')
qb_13 = pd.read_csv('best_ball_qb13.csv')

# %%
qb_13
# Out:
#          Full Name Position Best Ball Points Added (2017)  \
# 0    A.J. McCarron       QB                             0
# 1    Aaron Rodgers       QB                          26.6
# 2       Alex Smith       QB                          59.5
# 3      Alex Tanney       QB                             -
# 4      Andrew Luck       QB                             -
# ..             ...      ...                           ...
# 136     Tyler Bray       QB                             0
# 137  Tyler Huntley       QB                             -
# 138   Tyrod Taylor       QB                          17.3
# 139     Will Grier       QB                             -
# 140    Zach Wilson       QB                             -
#
#     Best Ball Points Added (2018) Best Ball Points Added (2019)  \
# 0                               0                             0
# 1                            40.3                          44.7
# 2                               0                             -
# ...

# %%
qb_df = qb_1.merge(qb_2.merge(
    qb_3.merge(
    qb_4.merge(
    qb_5.merge(
    qb_6.merge(
    qb_7.merge(
    qb_8.merge(
    qb_9.merge(
    qb_10.merge(
    qb_11.merge(
    qb_12.merge(
    qb_13, on='Full Name',how='inner'),on='Full Name',how='inner'),on='Full Name',how='inner'),
    on='Full Name',how='inner'),on='Full Name',how='inner'),on='Full Name',how='inner'),on='Full Name',how='inner'),
    on='Full Name',how='inner'),on='Full Name',how='inner'),on='Full Name',how='inner'),on='Full Name',how='inner'),
                  on='Full Name',how='inner')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Position_y'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(

# %%
qb_df
# Out:
#              Full Name Position    ADP Air Yards (2017)_x Air Yards (2018)_x  \
# 0        Aaron Rodgers       QB   98.7               1648               5163
# 1          Andy Dalton       QB  215.7               4115               3214
# 2       Baker Mayfield       QB  215.8                  -               4614
# 3   Ben Roethlisberger       QB  175.6               5417             5447.5
# 4       Blaine Gabbert       QB    240               1609                735
# ..                 ...      ...    ...                ...                ...
# 61     Trevor Lawrence       QB  145.1                  -                  -
# 62      Trevor Siemian       QB    676               3073                  -
# 63      Tua Tagovailoa       QB  128.3                  -                  -
# 64        Tyrod Taylor       QB  214.5               3715                862
# 65         Zach Wilson       QB  151.7                  -                  -
#
# ...
